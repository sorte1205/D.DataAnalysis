# %% [markdown]
# # Seaborn - Heatmap
#
# 데이터의 패턴, 특히 밀도와 분포를 빠르게 파악할 수 있게 해주는 시각적 도구.
#
# 행과 열을 가진 행렬 형태의 데이터를 색상으로 나타내어 각 셀의 값에 따라 색상이 변한다.
#
# ## #01. 준비작업
#
# ### [1] 패키치 참조

# %%
import warnings
warnings.filterwarnings(action='ignore')

import sys
import seaborn as sb
from matplotlib import pyplot as plt
from pandas import read_excel

# %% [markdown]
# ### [2] 그래프 초기화

# %%
plt.rcParams["font.family"] = 'AppleGothic' if sys.platform == 'darwin' else 'Malgun Gothic'
plt.rcParams["font.size"] = 9
plt.rcParams["figure.figsize"] = (15, 6)
plt.rcParams["figure.dpi"] = 200
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ### [3] 데이터 가져오기

# %%
origin = read_excel("https://data.hossam.kr/pydata/grade.xlsx", index_col='이름')
origin
# Out:
#     학년  성별  국어   영어  수학  과학
# 이름
# 철수   1  남자  98   77  88  64
# 영희   2  여자  88  120  62  72
# 민철   1  남자  92   70  83  79
# 수현   3  여자  63   60  31  71
# 호영   4  남자  75   50  90  88
# 영호   4  남자  80   88  91  72
# 용식   2  남자  82   88  79  90
# 나영   1  여자  90   92  81  95
# 석영   1  남자  91   90  89  80

# %% [markdown]
# ### [4] 데이터 전처리
#
# #### (1) 데이터 추출

# %%
df = origin[['국어','영어','수학','과학']].head(5)
df
# Out:
#     국어   영어  수학  과학
# 이름
# 철수  98   77  88  64
# 영희  88  120  62  72
# 민철  92   70  83  79
# 수현  63   60  31  71
# 호영  75   50  90  88

# %% [markdown]
# ## #02. Heatmap 시각화
#
# ### [1] 기본 사용 방법
#
# 성적표 데이터에 대한 점수 분포 시각화

# %%
plt.figure(figsize=(5, 4), dpi=120)
sb.heatmap(df)
plt.show()
plt.close()

# %% [markdown]
# ### [2] 데이터 값을 함께 표시하기
#
# `annot=True` 파라미터를 추가한다.

# %%
plt.figure(figsize=(5, 4), dpi=120)
sb.heatmap(df, annot=True)
plt.show()
plt.close()

# %% [markdown]
# ### [3] 출력 데이터의 형식 지정
#
# `fmt` 파라미터 적용. 일반적인 형식문자열 규칙에 따른다.
#
# 여기서는 소수점 한 자리까지 허용하는 실수 타입

# %%
plt.figure(figsize=(5, 4), dpi=120)
sb.heatmap(df, annot=True, fmt="0.1f")
plt.show()
plt.close()

# %% [markdown]
# ### [4] 각 셀 사이의 선 지정
#
# `linewidth` 파라미터로 선의 굵기를 지정
#
# `fmt` 속성의 `d`는 정수 형태의 출력을 의미

# %%
plt.figure(figsize=(5, 4), dpi=120)
sb.heatmap(df, annot=True, fmt="d", linewidth=0.5)
plt.show()
plt.close()

# %% [markdown]
# ### [5] 칼라맵 적용하기
#
# `cmap` 파라미터를 사용하여 색상맵의 이름을 지정

# %%
plt.figure(figsize=(5, 4), dpi=120)
sb.heatmap(df, annot=True, fmt="d", linewidth=.5, cmap="crest")
plt.show()
plt.close()

# %% [markdown]
# ### [6] 그래픽 옵션 추가
#
# `heatmap()` 메서드가 리턴하는 객체(`ax`)를 통해 그래픽 속성 관련 메서드를 사용할 수 있다.

# %%
plt.figure(figsize=(5, 4), dpi=120)

# 객체를 리턴받음
ax = sb.heatmap(df, annot=True, fmt="d", linewidth=.5, cmap="crest")

# x,y축의 라벨 변경
ax.set(xlabel="", ylabel="")

# x축의 변수 이름을 상단으로 이동
ax.xaxis.tick_top()

plt.show()
plt.close()
