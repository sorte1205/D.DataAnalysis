# %% [markdown]
# # Pie Plot
#
# 파이 차트는 한 변수에 대한 전체 대비 부문별 구성비를 보여주는 그래프
#
# 파이 차트는 명목형 또는 범주형 데이터에 사용된다.
#
# 변수에 다양한 수준이 있는 경우, 막대 차트를 이용한 빈도 그래프가 더 유용할 수 있다.
#
# ## #01. 준비작업
#
# ### [1] 패키지 참조

# %%
import sys
from pandas import read_excel
from matplotlib import pyplot as plt

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = read_excel("https://data.hossam.kr/pydata/poll.xlsx")
origin
# Out:
#     성별 결혼상태  나이  최종학력  월수입
# 0   남자   기혼  21   대학교   60
# 1   남자   기혼  22   대학원  100
# 2   남자   기혼  33   대학교  200
# 3   여자   미혼  33   대학교  120
# 4   남자   미혼  28   대학교   70
# 5   남자   기혼  21   대학원   80
# 6   여자   미혼  39   대학교  190
# 7   남자   기혼  32   대학교  100
# 8   남자   미혼  44  초등학교  120
# 9   남자   미혼  55   대학교  110
# 10  여자   미혼  46   대학원  150
# 11  남자   기혼  20   대학교   50
# 12  남자   미혼  31   대학교  210
# 13  남자   기혼  27   대학교   60
# 14  여자   기혼  21   대학원   80
# 15  여자   기혼  22   대학원   70
# 16  여자   미혼  41   대학원  250
# 17  여자   미혼  49   대학원  300
# 18  여자   기혼  29   대학교  100
# 19  여자   미혼  27   대학교   60
# 20  남자   미혼  32   대학원  150
# 21  남자   미혼  35   대학원  170
# 22  남자   미혼  47   대학교  130
# 23  남자   미혼  52   대학원  200
# 24  남자   기혼  59   대학원  230
# 25  남자   미혼  22  고등학교   60
# 26  남자   미혼  32   중학교   70
# 27  여자   미혼  41   대학교  130
# 28  남자   기혼  26   대학원   80
# 29  여자   미혼  56   대학교  150
# 30  남자   미혼  31   대학원  220
# 31  남자   미혼  42   대학원  200
# 32  남자   기혼  25   대학교   90
# 33  여자   기혼  26  고등학교   50
# 34  여자   기혼  24  고등학교   50
# 35  남자   미혼  34   대학교  100
# 36  남자   미혼  46   대학교  120
# 37  남자   미혼  56   대학원  349
# 38  남자   기혼  21   대학원   80
# 39  남자   미혼  23   대학교  100

# %% [markdown]
# ### [3] 그래프 초기화

# %%
plt.rcParams["font.family"] = 'AppleGothic' if sys.platform == 'darwin' else 'Malgun Gothic'
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## #02. 남여 성비 시각화
#
# ### [1] 데이터 전처리

# %%
sexRatio = origin['성별'].value_counts()
sexRatio
# Out:
# 성별
# 남자    27
# 여자    13
# Name: count, dtype: int64

# %% [markdown]
# ### [2] 표시할 데이터와 라벨 구분
#
# 반드시 리스트 타입으로 변환해야 하는 것은 아니다. 연속성을 갖는 모든 형태(리스트, 튜플, ndarray, 시리즈)가 모두 가능하다.

# %%
data = list(sexRatio.values)
labels = list(sexRatio.index)
print("데이터:", data)
print("라벨:", labels)
# Out:
# 데이터: [27, 13]
# 라벨: ['남자', '여자']

# %% [markdown]
# ### [3] 파이 그래프 구현
#
# `autopct`는 각 조각에 표시될 비율의 출력 형식을 형식문자열로 설정한다.

# %%
plt.figure()
plt.title("남여 성비")
plt.pie(data, labels=labels, autopct='%0.1f%%')
plt.show()
plt.close()

# %% [markdown]
# ```plain
# 총 40명의 조사 인원 중에서 남자의 비율은 67.5%, 여자의 비율은 32.5% 이다.
# ```
#
# ## #03. 최종 학력 비율 시각화
#
# ### [1] 데이터 전처리

# %%
eduRatio = origin['최종학력'].value_counts()
eduRatio
# Out:
# 최종학력
# 대학교     19
# 대학원     16
# 고등학교     3
# 초등학교     1
# 중학교      1
# Name: count, dtype: int64

# %% [markdown]
# ### [2] 그래프 구현
#
# | 파라미터 | 설명 |
# |---|---|
# | colors | 각 조각의 색상을 리스트로 지정 |
# | explode | 각 조각이 원점으로부터 떨어져 있는 정도. `0~1` 사이의 값을 갖는다. |
# | startangle | 그래프의 회전각 (기본값=`0`) |
# | shadow | 그림자 효과 사용 (기본값=`False`) |

# %%
plt.figure()
plt.title("최종 학력 비율")
plt.pie(eduRatio.values, labels=eduRatio.index, autopct='%0.1f%%',
        colors = ['#EF7C8E', '#BBE7FE', '#D3B5E5', '#FFD4DB', '#EFF1DB'],
        explode=[0, 0, 0.1, 0.2, 0.3],
        startangle=45,
        shadow=True)
plt.show()
plt.close()

# %% [markdown]
# ```plain
# 조사 인원의 최종 학력을 조사한 결과 대학교와 대학원을 졸업한 경우가 각각 47.5%, 40%로 압도적으로 높은 비율을 나타냈으며
# 대학교 미만의 학력은 초등학교 2.5%, 중학교 2.5%, 고등학교 7.5%로 대다수의 인원이 고학력 소지자로 파악되었다.
# ```
