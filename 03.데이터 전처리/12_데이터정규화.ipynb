# %% [markdown]
# # 데이터 정규화
#
# 데이터를 특정 범위나 척도로 변환하여 처리하거나 분석할 때 사용되는 기술
#
# 데이터 정규화의 목표는 서로 다른 단위나 범위를 가진 데이터를 동일한 기준으로 맞춤으로써, 데이터 분석이나 머신러닝 모델의 성능을 향상시키는 것
#
# ## #01. 준비과정
#
# ### [1] 패키지 참조
#
# `scikit-learn` 패키지의 설치가 필요하다.
#
# `scikit-learn`의 `preprocessing` 패키지 안에는 머신러닝에 적합한 데이터 전처리 기능을 제공하는 각종 클래스가 포함되어 있다.

# %%
from pandas import read_excel, DataFrame
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %% [markdown]
# ### [2] 샘플 데이터 가져오기
#
# 어느 간호학과 대학원에 지원한 학생들에 대한 합격/불합격 여부를 조사한 가상의 데이터이다.

# %%
origin = read_excel('https://data.hossam.kr/pydata/gradeuate.xlsx')
origin
# Out:
#      합격여부  필기점수  학부성적  병원경력
# 0       0   380  3.61     3
# 1       1   660  3.67     3
# 2       1   800  4.00     1
# 3       1   640  3.19     4
# 4       0   520  2.93     4
# ..    ...   ...   ...   ...
# 395     0   620  4.00     2
# 396     0   560  3.04     3
# 397     0   460  2.63     2
# 398     0   700  3.65     2
# 399     0   600  3.89     3
#
# [400 rows x 4 columns]

# %% [markdown]
# ## #02. Min-Max Scaler (Normalization, 정규화)
#
# 모든 데이터의 범위를 `0~1`로 변환하는 것.
#
# 데이터에서 최소값을 0으로, 최대값을 1로 매핑
#
# $정규화된 값 = (X - Xmin) / (Xmax - Xmin)$
#
# 이 방법은 데이터의 분포를 유지하면서 데이터를 특정 범위로 축소시키는 데에 유용
#
# ### [1] 직접 계산하기

# %%
df = origin.copy()

xmin = df['필기점수'].min()
xmax = df['필기점수'].max()

df['필기점수_MinMax(1)'] = (df['필기점수'] - xmin) / (xmax - xmin)
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)
# 0       0   380  3.61     3        0.275862
# 1       1   660  3.67     3        0.758621
# 2       1   800  4.00     1        1.000000
# 3       1   640  3.19     4        0.724138
# 4       0   520  2.93     4        0.517241
# ..    ...   ...   ...   ...             ...
# 395     0   620  4.00     2        0.689655
# 396     0   560  3.04     3        0.586207
# 397     0   460  2.63     2        0.413793
# 398     0   700  3.65     2        0.827586
# 399     0   600  3.89     3        0.655172
#
# [400 rows x 5 columns]

# %% [markdown]
# ### [2] sklearn 활용
#
# `sklearn`은 데이터 표준화를 위한 `MinMaxScaler` 클래스를 제공한다.
#
# 이 클래스에 데이터를 전달할 때는 `n행1열`로 구성된 2차 배열 형식이거나 표준화를 처리할 필드만 갖는 데이터 프레임이어야 한다.
#
# #### (1) 2차 배열로 처리하는 경우
#
# ##### 특정 필드의 값만 추출
#
# `1차 배열`형태로 추출된다.

# %%
n = df['필기점수'].values
n
# Out:
# array([380, 660, 800, 640, 520, 760, 560, 400, 540, 700, 800, 440, 760,
#        700, 700, 480, 780, 360, 800, 540, 500, 660, 600, 680, 760, 800,
#        620, 520, 780, 520, 540, 760, 600, 800, 360, 400, 580, 520, 500,
#        520, 560, 580, 600, 500, 700, 460, 580, 500, 440, 400, 640, 440,
#        740, 680, 660, 740, 560, 380, 400, 600, 620, 560, 640, 680, 580,
#        600, 740, 620, 580, 800, 640, 300, 480, 580, 720, 720, 560, 800,
#        540, 620, 700, 620, 500, 380, 500, 520, 600, 600, 700, 660, 700,
#        720, 800, 580, 660, 660, 640, 480, 700, 400, 340, 580, 380, 540,
#        660, 740, 700, 480, 400, 480, 680, 420, 360, 600, 720, 620, 440,
#        700, 800, 340, 520, 480, 520, 500, 720, 540, 600, 740, 540, 460,
#        620, 640, 580, 500, 560, 500, 560, 700, 620, 600, 640, 700, 620,
#        580, 580, 380, 480, 560, 480, 740, 800, 400, 640, 580, 620, 580,
#        560, 480, 660, 700, 600, 640, 700, 520, 580, 700, 440, 720, 500,
#        600, 400, 540, 680, 800, 500, 620, 520, 620, 620, 300, 620, 500,
#        700, 540, 500, 800, 560, 580, 560, 500, 640, 800, 640, 380, 600,
#        560, 660, 400, 600, 580, 800, 580, 700, 420, 600, 780, 740, 640,
#        540, 580, 740, 580, 460, 640, 600, 660, 340, 460, 460, 560, 540,
#        680, 480, 800, 800, 720, 620, 540, 480, 720, 580, 600, 380, 420,
#        800, 620, 660, 480, 500, 700, 440, 520, 680, 620, 540, 800, 680,
#        440, 680, 640, 660, 620, 520, 540, 740, 640, 520, 620, 520, 640,
#        680, 440, 520, 620, 520, 380, 560, 600, 680, 500, 640, 540, 680,
#        660, 520, 600, 460, 580, 680, 660, 660, 360, 660, 520, 440, 600,
#        800, 660, 800, 420, 620, 800, 680, 800, 480, 520, 560, 460, 540,
#        720, 640, 660, 400, 680, 220, 580, 540, 580, 540, 440, 560, 660,
#        660, 520, 540, 300, 340, 780, 480, 540, 460, 460, 500, 420, 520,
#        680, 680, 560, 580, 500, 740, 660, 420, 560, 460, 620, 520, 620,
#        540, 660, 500, 560, 500, 580, 520, 500, 600, 580, 400, 620, 780,
#        620, 580, 700, 540, 760, 700, 720, 560, 720, 520, 540, 680, 460,
#        560, 480, 460, 620, 580, 800, 540, 680, 680, 620, 560, 560, 620,
#        800, 640, 540, 700, 540, 540, 660, 480, 420, 740, 580, 640, 640,
#        800, 660, 600, 620, 460, 620, 560, 460, 700, 600], dtype=int64)

# %% [markdown]
# ##### 추출된 값의 차원 변환

# %%
n_re = n.reshape(-1, 1)
n_re
# Out:
# array([[380],
#        [660],
#        [800],
#        [640],
#        [520],
#        [760],
#        [560],
#        [400],
#        [540],
#        [700],
#        [800],
#        [440],
#        [760],
#        [700],
#        [700],
#        [480],
#        [780],
#        [360],
#        [800],
#        [540],
#        [500],
#        [660],
#        [600],
#        [680],
#        [760],
#        [800],
#        [620],
#        [520],
#        [780],
#        [520],
#        [540],
#        [760],
#        [600],
#        [800],
#        [360],
#        [400],
#        [580],
#        [520],
#        [500],
#        [520],
#        [560],
#        [580],
#        [600],
#        [500],
#        [700],
#        [460],
#        [580],
#        [500],
#        [440],
#        [400],
#        [640],
#        [440],
#        [740],
#        [680],
#        [660],
#        [740],
#        [560],
#        [380],
#        [400],
#        [600],
#        [620],
#        [560],
#        [640],
#        [680],
#        [580],
#        [600],
#        [740],
#        [620],
#        [580],
#        [800],
#        [640],
#        [300],
#        [480],
#        [580],
#        [720],
#        [720],
#        [560],
#        [800],
#        [540],
#        [620],
#        [700],
#        [620],
#        [500],
#        [380],
#        [500],
#        [520],
#        [600],
#        [600],
#        [700],
#        [660],
#        [700],
#        [720],
#        [800],
#        [580],
#        [660],
#        [660],
#        [640],
#        [480],
#        [700],
#        [400],
#        [340],
#        [580],
#        [380],
#        [540],
#        [660],
#        [740],
#        [700],
#        [480],
#        [400],
#        [480],
#        [680],
#        [420],
#        [360],
#        [600],
#        [720],
#        [620],
#        [440],
#        [700],
#        [800],
#        [340],
#        [520],
#        [480],
#        [520],
#        [500],
#        [720],
#        [540],
#        [600],
#        [740],
#        [540],
#        [460],
#        [620],
#        [640],
#        [580],
#        [500],
#        [560],
#        [500],
#        [560],
#        [700],
#        [620],
#        [600],
#        [640],
#        [700],
#        [620],
#        [580],
#        [580],
#        [380],
#        [480],
#        [560],
#        [480],
#        [740],
#        [800],
#        [400],
#        [640],
#        [580],
#        [620],
#        [580],
#        [560],
#        [480],
#        [660],
#        [700],
#        [600],
#        [640],
#        [700],
#        [520],
#        [580],
#        [700],
#        [440],
#        [720],
#        [500],
#        [600],
#        [400],
#        [540],
#        [680],
#        [800],
#        [500],
#        [620],
#        [520],
#        [620],
#        [620],
#        [300],
#        [620],
#        [500],
#        [700],
#        [540],
#        [500],
#        [800],
#        [560],
#        [580],
#        [560],
#        [500],
#        [640],
#        [800],
#        [640],
#        [380],
#        [600],
#        [560],
#        [660],
#        [400],
#        [600],
#        [580],
#        [800],
#        [580],
#        [700],
#        [420],
#        [600],
#        [780],
#        [740],
#        [640],
#        [540],
#        [580],
#        [740],
#        [580],
#        [460],
#        [640],
#        [600],
#        [660],
#        [340],
#        [460],
#        [460],
#        [560],
#        [540],
#        [680],
#        [480],
#        [800],
#        [800],
#        [720],
#        [620],
#        [540],
#        [480],
#        [720],
#        [580],
#        [600],
#        [380],
#        [420],
#        [800],
#        [620],
#        [660],
#        [480],
#        [500],
#        [700],
#        [440],
#        [520],
#        [680],
#        [620],
#        [540],
#        [800],
#        [680],
#        [440],
#        [680],
#        [640],
#        [660],
#        [620],
#        [520],
#        [540],
#        [740],
#        [640],
#        [520],
#        [620],
#        [520],
#        [640],
#        [680],
#        [440],
#        [520],
#        [620],
#        [520],
#        [380],
#        [560],
#        [600],
#        [680],
#        [500],
#        [640],
#        [540],
#        [680],
#        [660],
#        [520],
#        [600],
#        [460],
#        [580],
#        [680],
#        [660],
#        [660],
#        [360],
#        [660],
#        [520],
#        [440],
#        [600],
#        [800],
#        [660],
#        [800],
#        [420],
#        [620],
#        [800],
#        [680],
#        [800],
#        [480],
#        [520],
#        [560],
#        [460],
#        [540],
#        [720],
#        [640],
#        [660],
#        [400],
#        [680],
#        [220],
#        [580],
#        [540],
#        [580],
#        [540],
#        [440],
#        [560],
#        [660],
#        [660],
#        [520],
#        [540],
#        [300],
#        [340],
#        [780],
#        [480],
#        [540],
#        [460],
#        [460],
#        [500],
#        [420],
#        [520],
#        [680],
#        [680],
#        [560],
#        [580],
#        [500],
#        [740],
#        [660],
#        [420],
#        [560],
#        [460],
#        [620],
#        [520],
#        [620],
#        [540],
#        [660],
#        [500],
#        [560],
#        [500],
#        [580],
#        [520],
#        [500],
#        [600],
#        [580],
#        [400],
#        [620],
#        [780],
#        [620],
#        [580],
#        [700],
#        [540],
#        [760],
#        [700],
#        [720],
#        [560],
#        [720],
#        [520],
#        [540],
#        [680],
#        [460],
#        [560],
#        [480],
#        [460],
#        [620],
#        [580],
#        [800],
#        [540],
#        [680],
#        [680],
#        [620],
#        [560],
#        [560],
#        [620],
#        [800],
#        [640],
#        [540],
#        [700],
#        [540],
#        [540],
#        [660],
#        [480],
#        [420],
#        [740],
#        [580],
#        [640],
#        [640],
#        [800],
#        [660],
#        [600],
#        [620],
#        [460],
#        [620],
#        [560],
#        [460],
#        [700],
#        [600]], dtype=int64)

# %%
# 전치행렬

# transpose는 2차원에만 쓸 수 있다.

# n_re1 = DataFrame.t(n)
# n_re1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 n_re1 = DataFrame.t(n)
#       2 n_re1
#
# AttributeError: type object 'DataFrame' has no attribute 't'

# %%
# # 표준화 기능을 제공하는 객체를 생성
scaler = MinMaxScaler()

# 표준화를 적용할 필드를 scaler 객체에게 알려준다.
scaler.fit(n_re)

# 표준화 적용
df['필기점수_MinMax(2)'] = scaler.transform(n_re)

df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)
# 0       0   380  3.61     3        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172
#
# [400 rows x 6 columns]

# %% [markdown]
# #### (2) 표준화를 적용할 필드만 갖는 데이터 프레임을 사용하는 경우
#
# ##### 특정 필드만 추출

# %%
tmp = df.filter(['필기점수'])
tmp
# Out:
#      필기점수
# 0     380
# 1     660
# 2     800
# 3     640
# 4     520
# ..    ...
# 395   620
# 396   560
# 397   460
# 398   700
# 399   600
#
# [400 rows x 1 columns]

# %% [markdown]
# ##### 해당 필드에 대한 데이터 표준화

# %%
scaler = MinMaxScaler()
scaler.fit(tmp)
df['필기점수_MinMax(3)'] = scaler.transform(tmp)
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)  필기점수_MinMax(3)
# 0       0   380  3.61     3        0.275862        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172        0.655172
#
# [400 rows x 7 columns]

# %% [markdown]
# #### (3) 데이터 프레임 전체에 대한 처리
#
# ##### 표준화 처리
#
# 시리즈 객체로 반환되기 때문에 이 결과를 다시 데이터프레임으로 재구성해야 한다.
#
# `scaler.fit(origin)`: MinMaxScaler를 데이터에 맞추기 위해 사용됩니다. 이는 각 특성(변수)에 대해 최소값과 최대값을 계산하는 등의 작업을 수행합니다.
#
# `scaler.transform(origin)`: fit 단계에서 계산한 최소값과 최대값을 사용하여 데이터를 변환합니다. 각 변수에 대해 최소값을 0으로, 최대값을 1로 스케일링합니다.

# %%
scaler = MinMaxScaler()
scaler.fit(origin)
mms = scaler.transform(origin)
mms
# Out:
# array([[0.        , 0.27586207, 0.77586201, 0.66666667],
#        [1.        , 0.75862069, 0.81034487, 0.66666667],
#        [1.        , 1.        , 1.        , 0.        ],
#        ...,
#        [0.        , 0.4137931 , 0.21264375, 0.33333333],
#        [0.        , 0.82758621, 0.79885063, 0.33333333],
#        [0.        , 0.65517241, 0.93678167, 0.66666667]])

# %% [markdown]
# ##### DataFrame 으로 재구성

# %%
minmax_df = DataFrame(mms, index=origin.index, columns=origin.columns)
minmax_df
# Out:
#      합격여부      필기점수      학부성적      병원경력
# 0     0.0  0.275862  0.775862  0.666667
# 1     1.0  0.758621  0.810345  0.666667
# 2     1.0  1.000000  1.000000  0.000000
# 3     1.0  0.724138  0.534483  1.000000
# 4     0.0  0.517241  0.385058  1.000000
# ..    ...       ...       ...       ...
# 395   0.0  0.689655  1.000000  0.333333
# 396   0.0  0.586207  0.448276  0.666667
# 397   0.0  0.413793  0.212644  0.333333
# 398   0.0  0.827586  0.798851  0.333333
# 399   0.0  0.655172  0.936782  0.666667
#
# [400 rows x 4 columns]

# %% [markdown]
# ## #03. Standard Scaler (z-score, 표준화)
#
# 데이터를 평균이 `0`, 표준편차가 `1`인 표준정규분포를 따르도록 변환
#
# $ 정규화된 값 = (X - 평균) / 표준편차 $
#
# 데이터를 정규분포에 근사시켜서 이상치에 덜 민감하게 만들어 줌
#
# - 값들의 단위가 비슷하다면 MinMax
# - 값들의 단위가 상이하다면 Standard
# - 잘 모르겠으면 Standard
#
# > 분류 문제에서는 종속변수가 범주형(0, 1)이므로 종속변수는 표준화를 적용하지 않는다.
#
# ### [1] 직접 계산

# %%
평균 = df['학부성적'].mean()
표준편차 = df['학부성적'].std()
df['학부성적_Standard(1)'] = (df['학부성적'] - 평균) / 표준편차
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)  필기점수_MinMax(3)  \
# 0       0   380  3.61     3        0.275862        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172        0.655172
#
#      학부성적_Standard(1)
# 0            0.578348
# 1            0.736008
# 2            1.603135
# 3           -0.525269
# 4           -1.208461
# ..                ...
# 395          1.603135
# 396         -0.919418
# 397         -1.996758
# 398          0.683455
# 399          1.314093
#
# [400 rows x 8 columns]

# %% [markdown]
# ### [2] sklearn 활용

# %%
n = df['학부성적'].values.reshape(-1, 1)
n
# Out:
# array([[3.6099999 ],
#        [3.67000008],
#        [4.        ],
#        [3.19000006],
#        [2.93000007],
#        [3.        ],
#        [2.98000002],
#        [3.07999992],
#        [3.3900001 ],
#        [3.92000008],
#        [4.        ],
#        [3.22000003],
#        [4.        ],
#        [3.07999992],
#        [4.        ],
#        [3.44000006],
#        [3.86999989],
#        [2.55999994],
#        [3.75      ],
#        [3.80999994],
#        [3.17000008],
#        [3.63000011],
#        [2.81999993],
#        [3.19000006],
#        [3.3499999 ],
#        [3.66000009],
#        [3.6099999 ],
#        [3.74000001],
#        [3.22000003],
#        [3.28999996],
#        [3.77999997],
#        [3.3499999 ],
#        [3.4000001 ],
#        [4.        ],
#        [3.1400001 ],
#        [3.04999995],
#        [3.25      ],
#        [2.9000001 ],
#        [3.13000011],
#        [2.68000007],
#        [2.42000008],
#        [3.31999993],
#        [3.1500001 ],
#        [3.30999994],
#        [2.94000006],
#        [3.45000005],
#        [3.46000004],
#        [2.97000003],
#        [2.48000002],
#        [3.3499999 ],
#        [3.8599999 ],
#        [3.13000011],
#        [3.36999989],
#        [3.26999998],
#        [3.33999991],
#        [4.        ],
#        [3.19000006],
#        [2.94000006],
#        [3.6500001 ],
#        [2.81999993],
#        [3.18000007],
#        [3.31999993],
#        [3.67000008],
#        [3.8499999 ],
#        [4.        ],
#        [3.58999991],
#        [3.61999989],
#        [3.29999995],
#        [3.69000006],
#        [3.73000002],
#        [4.        ],
#        [2.92000008],
#        [3.3900001 ],
#        [4.        ],
#        [3.45000005],
#        [4.        ],
#        [3.3599999 ],
#        [4.        ],
#        [3.11999989],
#        [4.        ],
#        [2.9000001 ],
#        [3.06999993],
#        [2.71000004],
#        [2.91000009],
#        [3.5999999 ],
#        [2.98000002],
#        [3.31999993],
#        [3.48000002],
#        [3.27999997],
#        [4.        ],
#        [3.82999992],
#        [3.6400001 ],
#        [3.9000001 ],
#        [2.93000007],
#        [3.44000006],
#        [3.32999992],
#        [3.51999998],
#        [3.56999993],
#        [2.88000011],
#        [3.30999994],
#        [3.1500001 ],
#        [3.56999993],
#        [3.32999992],
#        [3.94000006],
#        [3.95000005],
#        [2.97000003],
#        [3.55999994],
#        [3.13000011],
#        [2.93000007],
#        [3.45000005],
#        [3.07999992],
#        [3.41000009],
#        [3.        ],
#        [3.22000003],
#        [3.83999991],
#        [3.99000001],
#        [3.45000005],
#        [3.72000003],
#        [3.70000005],
#        [2.92000008],
#        [3.74000001],
#        [2.67000008],
#        [2.8499999 ],
#        [2.98000002],
#        [3.88000011],
#        [3.38000011],
#        [3.53999996],
#        [3.74000001],
#        [3.19000006],
#        [3.1500001 ],
#        [3.17000008],
#        [2.78999996],
#        [3.4000001 ],
#        [3.07999992],
#        [2.95000005],
#        [3.56999993],
#        [3.32999992],
#        [4.        ],
#        [3.4000001 ],
#        [3.57999992],
#        [3.93000007],
#        [3.51999998],
#        [3.94000006],
#        [3.4000001 ],
#        [3.4000001 ],
#        [3.43000007],
#        [3.4000001 ],
#        [2.71000004],
#        [2.91000009],
#        [3.30999994],
#        [3.74000001],
#        [3.38000011],
#        [3.94000006],
#        [3.46000004],
#        [3.69000006],
#        [2.8599999 ],
#        [2.51999998],
#        [3.57999992],
#        [3.49000001],
#        [3.81999993],
#        [3.13000011],
#        [3.5       ],
#        [3.55999994],
#        [2.73000002],
#        [3.29999995],
#        [4.        ],
#        [3.24000001],
#        [3.76999998],
#        [4.        ],
#        [3.61999989],
#        [3.50999999],
#        [2.80999994],
#        [3.48000002],
#        [3.43000007],
#        [3.52999997],
#        [3.36999989],
#        [2.61999989],
#        [3.23000002],
#        [3.32999992],
#        [3.00999999],
#        [3.77999997],
#        [3.88000011],
#        [4.        ],
#        [3.83999991],
#        [2.78999996],
#        [3.5999999 ],
#        [3.6099999 ],
#        [2.88000011],
#        [3.06999993],
#        [3.3499999 ],
#        [2.94000006],
#        [3.53999996],
#        [3.75999999],
#        [3.58999991],
#        [3.47000003],
#        [3.58999991],
#        [3.06999993],
#        [3.23000002],
#        [3.63000011],
#        [3.76999998],
#        [3.30999994],
#        [3.20000005],
#        [4.        ],
#        [3.92000008],
#        [3.8900001 ],
#        [3.79999995],
#        [3.53999996],
#        [3.63000011],
#        [3.16000009],
#        [3.5       ],
#        [3.33999991],
#        [3.01999998],
#        [2.86999989],
#        [3.38000011],
#        [3.55999994],
#        [2.91000009],
#        [2.9000001 ],
#        [3.6400001 ],
#        [2.98000002],
#        [3.58999991],
#        [3.27999997],
#        [3.99000001],
#        [3.01999998],
#        [3.47000003],
#        [2.9000001 ],
#        [3.5       ],
#        [3.57999992],
#        [3.01999998],
#        [3.43000007],
#        [3.42000008],
#        [3.28999996],
#        [3.27999997],
#        [3.38000011],
#        [2.67000008],
#        [3.52999997],
#        [3.04999995],
#        [3.49000001],
#        [4.        ],
#        [2.8599999 ],
#        [3.45000005],
#        [2.75999999],
#        [3.80999994],
#        [2.96000004],
#        [3.22000003],
#        [3.03999996],
#        [3.91000009],
#        [3.33999991],
#        [3.17000008],
#        [3.6400001 ],
#        [3.73000002],
#        [3.30999994],
#        [3.21000004],
#        [4.        ],
#        [3.54999995],
#        [3.51999998],
#        [3.3499999 ],
#        [3.29999995],
#        [3.95000005],
#        [3.50999999],
#        [3.80999994],
#        [3.1099999 ],
#        [3.1500001 ],
#        [3.19000006],
#        [3.95000005],
#        [3.9000001 ],
#        [3.33999991],
#        [3.24000001],
#        [3.6400001 ],
#        [3.46000004],
#        [2.80999994],
#        [3.95000005],
#        [3.32999992],
#        [3.67000008],
#        [3.31999993],
#        [3.11999989],
#        [2.98000002],
#        [3.76999998],
#        [3.57999992],
#        [3.        ],
#        [3.1400001 ],
#        [3.94000006],
#        [3.26999998],
#        [3.45000005],
#        [3.0999999 ],
#        [3.3900001 ],
#        [3.30999994],
#        [3.22000003],
#        [3.70000005],
#        [3.1500001 ],
#        [2.25999999],
#        [3.45000005],
#        [2.77999997],
#        [3.70000005],
#        [3.97000003],
#        [2.54999995],
#        [3.25      ],
#        [3.16000009],
#        [3.06999993],
#        [3.5       ],
#        [3.4000001 ],
#        [3.29999995],
#        [3.5999999 ],
#        [3.1500001 ],
#        [3.98000002],
#        [2.82999992],
#        [3.46000004],
#        [3.17000008],
#        [3.50999999],
#        [3.13000011],
#        [2.98000002],
#        [4.        ],
#        [3.67000008],
#        [3.76999998],
#        [3.6500001 ],
#        [3.46000004],
#        [2.83999991],
#        [3.        ],
#        [3.63000011],
#        [3.71000004],
#        [3.27999997],
#        [3.1400001 ],
#        [3.57999992],
#        [3.00999999],
#        [2.69000006],
#        [2.70000005],
#        [3.9000001 ],
#        [3.30999994],
#        [3.48000002],
#        [3.33999991],
#        [2.93000007],
#        [4.        ],
#        [3.58999991],
#        [2.96000004],
#        [3.43000007],
#        [3.6400001 ],
#        [3.71000004],
#        [3.1500001 ],
#        [3.08999991],
#        [3.20000005],
#        [3.47000003],
#        [3.23000002],
#        [2.6500001 ],
#        [3.95000005],
#        [3.05999994],
#        [3.3499999 ],
#        [3.02999997],
#        [3.3499999 ],
#        [3.79999995],
#        [3.3599999 ],
#        [2.8499999 ],
#        [4.        ],
#        [3.43000007],
#        [3.11999989],
#        [3.51999998],
#        [3.77999997],
#        [2.80999994],
#        [3.26999998],
#        [3.30999994],
#        [3.69000006],
#        [3.94000006],
#        [4.        ],
#        [3.49000001],
#        [3.1400001 ],
#        [3.44000006],
#        [3.3599999 ],
#        [2.77999997],
#        [2.93000007],
#        [3.63000011],
#        [4.        ],
#        [3.8900001 ],
#        [3.76999998],
#        [3.75999999],
#        [2.42000008],
#        [3.36999989],
#        [3.77999997],
#        [3.49000001],
#        [3.63000011],
#        [4.        ],
#        [3.11999989],
#        [2.70000005],
#        [3.6500001 ],
#        [3.49000001],
#        [3.50999999],
#        [4.        ],
#        [2.61999989],
#        [3.01999998],
#        [3.8599999 ],
#        [3.3599999 ],
#        [3.17000008],
#        [3.50999999],
#        [3.04999995],
#        [3.88000011],
#        [3.38000011],
#        [3.75      ],
#        [3.99000001],
#        [4.        ],
#        [3.03999996],
#        [2.63000011],
#        [3.6500001 ],
#        [3.8900001 ]])

# %%
scaler = StandardScaler()
scaler.fit(n)
df['학부성적_Standard(2)'] = scaler.transform(n)
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)  필기점수_MinMax(3)  \
# 0       0   380  3.61     3        0.275862        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172        0.655172
#
#      학부성적_Standard(1)  학부성적_Standard(2)
# 0            0.578348          0.579072
# 1            0.736008          0.736929
# 2            1.603135          1.605143
# 3           -0.525269         -0.525927
# 4           -1.208461         -1.209974
# ..                ...               ...
# 395          1.603135          1.605143
# 396         -0.919418         -0.920570
# 397         -1.996758         -1.999259
# 398          0.683455          0.684310
# 399          1.314093          1.315739
#
# [400 rows x 9 columns]

# %% [markdown]
# ## #04. RobustScaler
#
# 이상치가 존재할 경우 사용하는 방법.
#
# 이상치(outliers)에 영향을 최소화하여 데이터를 스케일링하는 방법
#
# 이상치가 포함된 데이터를 표준화(Standardization)하거나 정규화(Normalization)할 때, 이상치의 영향으로 전체 데이터의 분포가 왜곡됨
#
# RobustScaler는 이 문제를 해결하기 위해 중앙값과 사분위수를 사용하여 데이터를 스케일링 함
#
# $ 정규화된 값 = (X - median) / iqr $
#
# $ iqr = Q3 - Q1 $
#
# ### [1] 직접계산

# %%
중앙값 = df['병원경력'].median()
iqr = df['병원경력'].quantile(0.75) - df['병원경력'].quantile(0.25)
df['병원경력_Robust(1)'] = (df['병원경력'] - 중앙값) / iqr
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)  필기점수_MinMax(3)  \
# 0       0   380  3.61     3        0.275862        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172        0.655172
#
#      학부성적_Standard(1)  학부성적_Standard(2)  병원경력_Robust(1)
# 0            0.578348          0.579072             1.0
# 1            0.736008          0.736929             1.0
# 2            1.603135          1.605143            -1.0
# 3           -0.525269         -0.525927             2.0
# 4           -1.208461         -1.209974             2.0
# ..                ...               ...             ...
# 395          1.603135          1.605143             0.0
# 396         -0.919418         -0.920570             1.0
# 397         -1.996758         -1.999259             0.0
# 398          0.683455          0.684310             0.0
# 399          1.314093          1.315739             1.0
#
# [400 rows x 10 columns]

# %% [markdown]
# ### [2] sklearn 활용

# %%
n = df['병원경력'].values.reshape(-1, 1)
scaler = RobustScaler()
scaler.fit(n)
df['병원경력_Robust(2)'] = scaler.transform(n)
df
# Out:
#      합격여부  필기점수  학부성적  병원경력  필기점수_MinMax(1)  필기점수_MinMax(2)  필기점수_MinMax(3)  \
# 0       0   380  3.61     3        0.275862        0.275862        0.275862
# 1       1   660  3.67     3        0.758621        0.758621        0.758621
# 2       1   800  4.00     1        1.000000        1.000000        1.000000
# 3       1   640  3.19     4        0.724138        0.724138        0.724138
# 4       0   520  2.93     4        0.517241        0.517241        0.517241
# ..    ...   ...   ...   ...             ...             ...             ...
# 395     0   620  4.00     2        0.689655        0.689655        0.689655
# 396     0   560  3.04     3        0.586207        0.586207        0.586207
# 397     0   460  2.63     2        0.413793        0.413793        0.413793
# 398     0   700  3.65     2        0.827586        0.827586        0.827586
# 399     0   600  3.89     3        0.655172        0.655172        0.655172
#
#      학부성적_Standard(1)  학부성적_Standard(2)  병원경력_Robust(1)  병원경력_Robust(2)
# 0            0.578348          0.579072             1.0             1.0
# 1            0.736008          0.736929             1.0             1.0
# 2            1.603135          1.605143            -1.0            -1.0
# 3           -0.525269         -0.525927             2.0             2.0
# 4           -1.208461         -1.209974             2.0             2.0
# ..                ...               ...             ...             ...
# 395          1.603135          1.605143             0.0             0.0
# 396         -0.919418         -0.920570             1.0             1.0
# 397         -1.996758         -1.999259             0.0             0.0
# 398          0.683455          0.684310             0.0             0.0
# 399          1.314093          1.315739             1.0             1.0
#
# [400 rows x 11 columns]
